# %% [markdown]
# ---
# ---
# # TUTORIAL 1: INTRODUCTION TO JUPYTER NOTEBOOKS
#
# <div style="text-align: center;">
# <img src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQPjNwqLw3jJppcrji2LJRDysRJ2xH9pdZVeLG8AyC0aA&s=10" alt="jupyter logo" width="500"/>
# </div>
#
#
# Welcome. _This_ is a Jupyter Notebook. You might wonder, _why is it called a "Jupyter" notebook?_ It turns out "Jupyter" is a portmaneau of _ju-pyt-r_, honouring the three core programming languages Julia, Python, and R.
#
# Notebooks like these are a useful component of the data science workflow because they seamlessly integrate plain text, mathematical equations, as well as code and output from code. This allows a data scientist to perform analyses and communicate the results of those analyses in a single, user-friendly document. In this tutorial, you will begin to gain experience using a Jupyter notebook.

# %% [markdown]
# ---
# ---
# # Introduction to Cells
#
# As you will see, a notebook is composed of a collection of "cells". These cells can be interpreted in one of three ways:
#
# * **Code:** As the name suggests, a code cell is one with which you write and execute code. In DATSC101, Python is the programming language we'll be using, and so our notebooks will be setup such that the code cells expect Python code.
# * **Markdown:** Markdown is a markup language that uses simple keyboard symbols to create formatted text. Anytime you want to type text that is not code, it will be in Markdown cell.
# * **Raw:** A cell type whose content is completely ignored by the notebook kernel and never executed. We won't make use of these in DATSC101.
#
# This text you're reading right now is stored in a cell. A Markdown cell to be specific. See for yourself. Double-click the text and you will see the nicely formatted text revert back to it's representation in the plain-text editor. The plain-text version is the source, and when the cell is "Run", the text is rendered nicely with the desired formatting.

# %% [markdown]
# ---
# ## Running a Cell
#
# How do you "Run" a cell? A few ways:
#
# * You can click the play button (&#x25B6;) at the top of the notebook.
# * You can click the "Run" menu from the top of the JupyterHub application, and from there you can choose to run one or more cells.
# * You can use a keyboard shortcut
#     * Mac:
#         * Run cell in place: Command + Return
#         * Run cell and insert below: Option + Return
#         * Run cell and select below: Shift + Return
#     * Windows
#         * Run cell in place: Ctrl + Enter
#         * Run cell and insert below: Alt + Enter
#         * Run cell and select below: Shift + Enter

# %% [markdown]
# ---
# ## Manipulating Cells
#
# You see that some of these keyboard shortcuts involves creating new cells. It turns out we can add, delete, move, and duplicate cells. The _cell toolbar_ is probably the easiest way to do this. The cell toolbar is the floating menu in the topright of cell that looks like this:
#
# <div style="text-align: center;">
#   <img src="https://raw.githubusercontent.com/ntstevens/DATSC101/refs/heads/main/images/cell_toolbar.jpg" alt="cell toolbar" />
# </div>
#
# The icons above have the following functions, respectively:
#
# * Copy the current cell and create an exact duplicate below it.
# * Move the current cell up one position.
# * Move the current cell down one position.
# * Insert a new cell above the current one.
# * Insert a new cell below the current one. This can also be done by clicking the plus button (&#43;) at the top of the notebook.
# * Delete the current cell. This can also be done by clicking the scissor button (&#x2702;) at the top of the notebook.

# %% [markdown]
# ---
# ## Changing a Cell's Type
#
# As you may have noticed, newly created cells are by default code cells, but you can change this. To change a given cell's type, put your cursor in the cell and select the desired type from the dropdown menu at the top of the notebook.
#
# You can also use keyboard shortcuts for this:
#
# * Code &#8594; Markdown: Esc + M
# * Markdown &#8594; Code: Esc + Y

# %% [markdown]
# ---
# ---
# # Introduction to Markdown
#
# At this point in your studies, you are undoubtedly familiar with word processors like Microsoft Word or Google Docs. In those environments, text formatting involves highlighting text and clicking a button. Here, you will gain experience with Markdown, which only requires keyboard symbols to format text.

# %% [markdown]
# ---
# ## 📝 Text Basics
#
# * **Bold text:** Wrap words in two asterisks `**like this**` to make them **like this**.
# * **Italic text:** Wrap words in single asterisks `*like this*` to make them *like this*.
# * **Strikethrough:** Wrap words in two tildes `~~like this~~` to make them ~~like this~~.
# * **Underlined text:** Unfortunately, there is no built-in syntax to underline textin Markdown.
# * **Combined emphasis:** Wrap words in three asterisks `***bold and italic***` for ***bold and italic***.

# %% [markdown]
# ---
# ## 🏛️ Headings and Structure
#
# Instead of selecting "Heading 1" or "Heading 2" from a dropdown menu, use the hash # symbol at the start of a line. Always put a space after the hash symbols.
#
# For example, this:
#
# ```
# # Title (Heading 1)
# ## Major Section (Heading 2)
# ### Subsection (Heading 3)
# #### Sub-subsection (Heading 4)
#
# ```
# renders as this:
#
# # Title (Heading 1)
# ## Major Section (Heading 2)
# ### Subsection (Heading 3)
# #### Sub-subsection (Heading 4)

# %% [markdown]
# ---
# ## 📋 Lists
#
# Markdown formats lists automatically when you start a line with standard listing characters.
#
# ### Bulleted Lists
#
# Use a dash `-` or an asterisk `*` followed by a space. Indent two spaces for sub-bullets.
#
# For example, this:
#
# ```
# * First main point
# * Second main point
#   * Sub-point under the second point
# ```
# randers as this:
#
# * First main point
# * Second main point
#   * Sub-point under the second point
#
#
# ### Numbered Lists
#
# Type the number followed by a period and a space. Markdown automatically fixes the numbering sequence when rendered, even if you type 1. for every item.
#
# For example, this:
#
# ```
# 1. First step
# 2. Second step
# 1. Third step (Markdown will correctly display this as 3.)
# ```
# renders as this:
# 1. First step
# 2. Second step
# 1. Third step (Markdown will correctly display this as 3.)

# %% [markdown]
# ---
# ## 🔗 Links and Images
#
# Instead of using a "Insert Hyperlink" dialog box, use combinations of brackets.
#
# ### Web Links
# * Put the clickable text in square brackets and the URL in parentheses.
#     * `[Visit Google](https://google.com)` becomes [Visit Google](https://google.com).
#
#
# ### Image
# * Use the exact same format as a link, but add an exclamation mark `!` at the very beginning.
#     * `![Image Description](https://cdn.myportfolio.com/45214904-6a61-4e23-98d6-b140f8654a40/9e9d8fe3-6822-4c9f-b272-acfb4838b799_rwc_312x23x1298x1015x1280.jpg?h=e8265ce4e3a2534d6b16cdf6c7ba04c9)` becomes ![Image Description](https://cdn.myportfolio.com/45214904-6a61-4e23-98d6-b140f8654a40/9e9d8fe3-6822-4c9f-b272-acfb4838b799_rwc_312x23x1298x1015x1280.jpg?h=e8265ce4e3a2534d6b16cdf6c7ba04c9)
#
#     * If you want to adjust the image's size, you can alternatively use `<img src="image_url" alt="Image Description" width="500"/>` which becomes
#     <img src="https://cdn.myportfolio.com/45214904-6a61-4e23-98d6-b140f8654a40/9e9d8fe3-6822-4c9f-b272-acfb4838b799_rwc_312x23x1298x1015x1280.jpg?h=e8265ce4e3a2534d6b16cdf6c7ba04c9" alt="Image Description" width="500"/>
#
#     * We can also center images! Click into this cell to see how:
#     <div style="text-align: center;">
#     <img src="https://cdn.myportfolio.com/45214904-6a61-4e23-98d6-b140f8654a40/9e9d8fe3-6822-4c9f-b272-acfb4838b799_rwc_312x23x1298x1015x1280.jpg?h=e8265ce4e3a2534d6b16cdf6c7ba04c9" alt="Image Description" width="500"/>
#     </div>
#
# \* **Acknowledgement:** this image comes from [Allison Horst](https://allisonhorst.com/allison-horst), an artist who makes fun data science-related artwork.

# %% [markdown]
# ---
# ## 💻 Faux Code
#
# Word processors often struggle to format computer code neatly. Markdown makes it simple.
#
# ### Inline Code
#
# To highlight a variable name, file path, or short command inside a sentence, wrap it in single backticks `` ` `` (found next to the `1` key).
# * Example: Use the `print()` function.
#
# ### Code Blocks
# To display a multi-line block of programming code, wrap the entire block in triple backticks `` ``` ``.
#
# ```
# def hello_world():
#     print("Hello, student!")
# ```
#
# You can type the language name right after the first set of backticks to enable color coding.
#
# ```python
# def hello_world():
#     print("Hello, student!")
# ```
#
# To be clear, we aren't writing code that can be executed here; we're simply formatting text to look like it's code. If we'd like the code to run, we should change the cell type.

# %% [markdown]
# ---
# ## 📐 Math Formulas
#
# For math equations, Jupyter uses LaTeX (pronounced _lay-tech_) syntax. Wrap your math in dollar signs `$` instead of using a complex equation editor
#
# ### Inline Math
#
# Wrap equations in single dollar signs `$` to keep them in the sentence line.
# * `$E = mc^2$` renders as $E = mc^2$.
#
# ### Centered Equations
#
# Wrap equations in double dollar signs `$$` to center them on their own line.
# * `$$\frac{1}{2}$$` creates a centered fraction: $$\frac{1}{2}$$
#
# For a fairly comprehensive overview of LaTeX syntax, see [this cheatsheet](https://webhome.auburn.edu/~tamtiny/Symbols.pdf).

# %% [markdown]
# ---
# ## 🔍 Check Your Understanding
#
# The cell below, titled "Project: Customer Churn Analysis", provides an example of formatted text that you should be able to recreate, based on what you've learned above.
#
# In the empty cell below, try to recreate the "Project: Customer Churn Analysis" cell!

# %% [markdown]
# #### Project: Customer Churn Analysis
#
# ##### 1. Executive Summary
# In this analysis, we build a **predictive model** to identify customers at risk of leaving our service. We will clean the dataset, extract *key performance indicators*, and train a machine learning algorithm.
#
# ##### 2. Pipeline Steps
# * Data ingestion from SQL database
# * Feature engineering
#   * Convert categorical variables to numeric indicators.
# * Model training and evaluation
#
# ##### 3. Core Metrics
# We evaluate model performance by calculating the Log Loss metric to optimize probabilities:
#
# $$L(y, p) = -(y \log(p) + (1 - y) \log(1 - p))$$
#
# Inside our notebook, we execute this evaluation using the `evaluate_model_performance` function.

# %% [markdown]
# ---
# ## ✨ Additional Practice
#
# * Take 1-minute to review this handy cheat sheet that summarizes what we learned above, as well as some additional commands: https://commonmark.org/help/
#
# * Take an additional 10-minutes to work through this tutorial and quiz to really hone your Markdown skills: https://commonmark.org/help/tutorial/

# %% [markdown]
# ---
# ---
# # Introduction to Python
#
# Python is a popular, general-purpose programming language designed to be easy to read and simple to write. It's become the undisputed industry-standard when it comes to data science and AI, so we will be using it extensively in this course. By the end of the course you will all be fluent in Python.
#
# Today we'll start with a very basic introduction: how to use Python as a calculator.

# %% [markdown]
# ---
# ## 🧮 Basic Mathematical Operations
#
# Unlike above, we now want our cells to be "code" cells. Otherwise, the notebook will not interpret the Python code correctly when the cell is run. [Exercise: what happens if you change one of the cell types below?]
#
# Below is a code cell carrying out a very basic calculation.

# %%
# Addition
3 + 2
# Out:
# 5

# %% [markdown]
# Notice:
#
# * Below the code cell is a result; the result of running the cell's code. We call this the code's **output**.
# * In the code cell there is some green text preceded by the number sign `#`. This is called a **comment** and programmers include these to explain what a piece of code is doing. Note that when a code cell is run, comments are not treated like code--they're ignored. [Exercise: what happens if you delete the `#` symbol and try to run the cell? What happens if you delete the entire comment?]
#
# Let's carry on and see how to do other basical mathematical operations.

# %%
# Subtraction
3 - 2
# Out:
# 1

# %%
# Multiplication
3 * 2
# Out:
# 6

# %%
# Division
3 / 2
# Out:
# 1.5

# %%
# Remainder
3 % 2
# Out:
# 1

# %%
# Exponentiation
3 ** 2
# Out:
# 9

# %%
# Square root
3 ** 0.5
# Out:
# 1.7320508075688772

# %%
# BEDMAS
(3 + 2) ** 2 / (2 * 3)
# Out:
# 4.166666666666667

# %% [markdown]
# ---
# ## 📚 Libraries and Functions
#
# We've just about exhausted the mathematical operations "base" Python is capable of. When we need to perform a more advanced calculation, we're going to need to import a **library**.
#
# What is a library?
# * 🧙 Think of yourself as a wizard capable of many advanced spells, but you need your spellbook in order to do them.
# * 🧑‍🍳 Think of yourself as a chef capable of many advanced recipes, but you need your cookbook in order to do them.
# * 🧑‍🔬 Data scientists are similar. We can apply many advanced *functions*, but we need access to the library containing those functions in order to use them.
#
# What is a function?
#
# * A function is a reusable, self-contained block of code designed to perform a specific task.
#
# Today we'll work with a library called `numpy` (pronounced *numb-pie*), which is commonly used for scientific computing in Python. We'll use is to perform some mathametical calculations available to us via functions.
#
# Let's revisit the square root calculation we performed above:

# %%
3 ** 0.5
# Out:
# 1.7320508075688772

# %% [markdown]
# There is a dedicated function for this in `numpy` called `sqrt()`. In order to use it, we need to import the library:

# %%
import numpy

# %% [markdown]
# That was easy. Now we have access to any and all functions stored in the `numpy` library. Let's test out the `sqrt()` function.

# %%
numpy.sqrt(3)
# Out:
# 1.7320508075688772

# %% [markdown]
# Success! And this agrees with the result above.
#
# Notice the syntax we used to run the `sqrt()` function. This is an example of the following broader principle:
#
# <div style="text-align: center;">
#   <img src="https://raw.githubusercontent.com/ntstevens/DATSC101/59298f312bb0f45183441edf648e4ad3cca240c4/images/function_example.svg" alt="function example" />
# </div>
#
# Let's explore some other functions in `numpy`.

# %%
# Round
numpy.round(4.7)
# Out:
# 5.0

# %%
# Absolute value
numpy.abs(-3)
# Out:
# 3

# %%
# Exponents
numpy.power(2,3)
# Out:
# 8

# %% [markdown]
# But writing out the library name is inefficient and annoying! We can simplify things by importing `numpy` under a shorter **alias**.

# %%
import numpy as np

# %% [markdown]
# Now, anytime we need to refer to `numpy` we can do so using the alias `np`.

# %%
np.sqrt(3)
# Out:
# 1.7320508075688772

# %%
np.round(4.7)
# Out:
# 5.0

# %%
np.abs(-3)
# Out:
# 3

# %%
np.power(2,3)
# Out:
# 8

# %% [markdown]
# `numpy` contains many functions and vast capability. We'll return to this library often throughout the course as we expand our toolboxes. [Click here](https://numpy.org/) if you want to browse the `numpy` documentation to see what else it can do.

# %% [markdown]
# ---
# ## 🔍 Check Your Understanding
# Try each of the exercises below with and without `numpy`. There is one code cell for each attempt.

# %% [markdown]
# 1. Perform the following calculation: $$\left(\frac{100}{4}\right) \times 2 + |5 - 15|$$

# %% [markdown]
# 2. Perform the following calculation: $$\sqrt{\frac{(10-7)^2}{3\times(1+2)}}$$

# %% [markdown]
# 3. Calculate the length ($x$) of the hypotenuse of this right angle triangle:
#
# <div style="text-align: center;">
#   <img src="https://raw.githubusercontent.com/ntstevens/DATSC101/59298f312bb0f45183441edf648e4ad3cca240c4/images/pythagoras.svg" alt="pythagoras example" width = "300" />
# </div>
